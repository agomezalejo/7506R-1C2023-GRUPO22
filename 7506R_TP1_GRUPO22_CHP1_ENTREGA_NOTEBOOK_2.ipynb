# %% [markdown]
# # **Trabajo Práctico 1 : Reservas de Hotel**
# ### *Continuación Checkpoint 1 - Notebook 2*
# ###Grupo 22: JARVIS
# + 107666	CELANO MINIG, NICOLÁS FRANCO
# + 108642	RANDO, JULIAN AGUSTIN
# + 106421	GOMEZ, ALEJO

# %% [markdown]
# Importamos las bibliotecas a utilizar para continuar con el trabajo e importamos el dataset modificado

# %%
import pandas as pd
import numpy as np
from IPython.display import display
import datetime
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.spatial.distance import mahalanobis
from google.colab import files
from sklearn.ensemble import IsolationForest

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=UserWarning)
pd.options.mode.chained_assignment = None
pd.set_option('display.max_columns', None)

colors = sns.color_palette(n_colors=15)

hotels_test_url = 'https://raw.githubusercontent.com/agomezalejo/7506R-1C2023-GRUPO22/main/df_hotel_modificado.csv'
df_original = pd.read_csv(hotels_test_url)
df_hotel = df_original.copy()
df_hotel_mahalanobis = df_hotel.copy()

# %% [markdown]
# ##Valores Atípicos

# %% [markdown]
# ### **Relaciones multivariadas**

# %%
def boxplot_mahalanobis_entre(variable_uno, variable_dos):
    global df_hotel_mahalanobis, df_hotel
    
    X = df_hotel[[variable_uno, variable_dos]]
    X_centered = X - np.mean(X, axis=0)
    cov = np.cov(X_centered, rowvar=False)
    inv_covmat = np.linalg.inv(cov)
    dist = []
    for i in range(X.shape[0]):
        dist.append(mahalanobis(X_centered.iloc[i], np.mean(X, axis=0), inv_covmat))

    nombre_mahala = 'mahala_dist_'+variable_uno+'_'+variable_dos
    print(nombre_mahala)
    df_hotel_mahalanobis[nombre_mahala] = dist

    sns.boxplot(y=df_hotel_mahalanobis[nombre_mahala])
    plt.title('Boxplot de la matriz de Mahalanobis para '+variable_uno+' y '+variable_dos)
    plt.show()

# %%
def eliminar(df):
    global df_hotel, df_hotel_mahalanobis
    indices_a_eliminar = df.index
    df_hotel = df_hotel.drop(indices_a_eliminar)
    df_hotel = df_hotel.reset_index(drop=True)

    df_hotel_mahalanobis = df_hotel_mahalanobis.drop(indices_a_eliminar)
    df_hotel_mahalanobis = df_hotel_mahalanobis.reset_index(drop=True)
    return

# %% [markdown]
# #### **adults y children**

# %% [markdown]
# Veamos el diagrama de dispersión.

# %%
sns.scatterplot(x=df_hotel['adults'], y=df_hotel['children'], hue=df_hotel['is_canceled'])
plt.title('Diagrama de Dispersión adults vs children')
plt.show()

# %% [markdown]
# Observamos que existen casos en donde aults y children son 0, lo que resulta imposible.

# %%
df_sin_adultos = df_hotel[df_hotel['adults'] == 0]
df_sin_niños_adultos = df_sin_adultos[df_sin_adultos['children']==0]
print("Cantidad de casos en donde adults y children valen cero:",df_sin_niños_adultos.shape[0])
# Out:
# Cantidad de casos en donde adults y children valen cero: 71

# %% [markdown]
# Procedemos a eliminarlos.

# %%
eliminar(df_sin_niños_adultos)

# %% [markdown]
# #### **total_of_special_requests y adr**

# %%
boxplot_mahalanobis_entre('total_of_special_requests', 'adr')
# Out:
# mahala_dist_total_of_special_requests_adr

# %% [markdown]
# Observamos con mayor atención a los casos mayores a 6.

# %%
df_superiores = df_hotel_mahalanobis[df_hotel_mahalanobis['mahala_dist_total_of_special_requests_adr']>6]
df_superiores
# Out:
#               hotel  lead_time  arrival_date_year arrival_date_month  \
# 9710   Resort Hotel         24               2017              March
# 17904    City Hotel        120               2017              April
# 19747    City Hotel          0               2016            October
# 23686    City Hotel         46               2016           November
# 29640    City Hotel         51               2017               June
# 30715    City Hotel        207               2017               June
# 44488    City Hotel        125               2016          September
# 46031  Resort Hotel         66               2015           November
# 48217    City Hotel         30               2015            October
# 56499  Resort Hotel        241               2015           December
# 57010    City Hotel         30               2015            October
# 57113    City Hotel        205               2017             August
# 60747    City Hotel        105               2016          September
#
#        arrival_date_day_of_month  stays_in_weekend_nights  \
# 9710                          29                        0
# 17904                         17                        1
# 19747                         29                        1
# 23686                         18                        2
# 29640                          9                        2
# 30715                         24                        2
# 44488                          4                        4
# 46031                         19                        1
# 48217                         14                        0
# 56499                          4                        2
# 57010                         14                        0
# 57113                         29                        0
# 60747                         29                        1
#
#        stays_in_week_nights  adults  children  babies meal country  \
# 9710                      2       2         0       0   BB     BRA
# 17904                     4       2         0       0   SC     DEU
# 19747                     1       2         0       0   BB     ESP
# 23686                     3       2         0       0   BB     BRA
# 29640                     3       2         0       0   BB     PRT
# 30715                     2       2         0       0   SC     USA
# 44488                     6       2         0       0   BB     ISR
# 46031                     3       2         0       0   BB     IRL
# 48217                     3       2         0       0   BB     BEL
# 56499                     2       1         0       0   BB     PRT
# 57010                     3       2         0       0   BB     BEL
# 57113                     2       2         0       0   SC     DEU
# 60747                     3       2         0       0   BB     IRL
#
#       market_segment distribution_channel  is_repeated_guest  \
# 9710          Direct                TA/TO               True
# 17904      Online TA                TA/TO              False
# 19747      Online TA                TA/TO               True
# 23686      Online TA                TA/TO              False
# 29640         Direct               Direct              False
# 30715      Online TA                TA/TO              False
# 44488      Online TA                TA/TO              False
# 46031      Online TA                TA/TO              False
# 48217      Online TA                TA/TO              False
# 56499         Direct                TA/TO               True
# 57010      Online TA                TA/TO              False
# 57113      Online TA                TA/TO              False
# 60747  Offline TA/TO                TA/TO              False
#
#        previous_cancellations  previous_bookings_not_canceled  \
# 9710                        0                               4
# 17904                       0                               0
# 19747                       0                               0
# 23686                       0                               0
# 29640                       0                               0
# 30715                       0                               0
# 44488                       0                               0
# 46031                       0                               0
# 48217                       0                               0
# 56499                       1                               3
# 57010                       0                               0
# 57113                       0                               0
# 60747                       0                               0
#
#       reserved_room_type assigned_room_type  booking_changes deposit_type  \
# 9710                   D                  D                0   No Deposit
# 17904                  A                  A                0   No Deposit
# 19747                  A                  A                1   No Deposit
# 23686                  A                  A                0   No Deposit
# 29640                  D                  D                0   No Deposit
# 30715                  A                  A                0   No Deposit
# 44488                  A                  A                0   No Deposit
# 46031                  A                  D                1   No Deposit
# 48217                  A                  A                0   No Deposit
# 56499                  A                  E                1   No Deposit
# 57010                  A                  A                0   No Deposit
# 57113                  A                  A                0   No Deposit
# 60747                  A                  A                0   No Deposit
#
#            agent      company  days_in_waiting_list    customer_type     adr  \
# 9710       250.0  not company                     0            Group   63.00
# 17904        9.0  not company                     0  Transient-Party  108.00
# 19747        9.0  not company                     0        Transient   12.00
# 23686        7.0  not company                     0        Transient   68.07
# 29640  not agent  not company                     0        Transient   78.00
# 30715        9.0  not company                     0        Transient   99.00
# 44488        7.0  not company                     0        Transient   99.79
# 46031      240.0  not company                     0        Transient   32.40
# 48217        9.0  not company                     0         Contract   96.30
# 56499      240.0  not company                     0        Transient   29.00
# 57010        9.0  not company                     0         Contract   96.30
# 57113        9.0  not company                     0        Transient   99.00
# 60747  not agent  not company                     0        Transient   96.90
#
#        required_car_parking_spaces  total_of_special_requests  is_canceled  \
# 9710                             0                          5        False
# 17904                            0                          5        False
# 19747                            0                          4        False
# 23686                            0                          5        False
# 29640                            0                          5         True
# 30715                            0                          5        False
# 44488                            0                          5        False
# 46031                            0                          4        False
# 48217                            0                          5        False
# 56499                            0                          4        False
# 57010                            0                          5        False
# 57113                            0                          5        False
# 60747                            0                          5        False
#
#        mahala_dist_total_of_special_requests_adr
# 9710                                    6.609429
# 17904                                   6.017795
# 19747                                   6.370019
# 23686                                   6.537626
# 29640                                   6.400541
# 30715                                   6.127338
# 44488                                   6.117533
# 46031                                   6.008971
# 48217                                   6.161117
# 56499                                   6.068231
# 57010                                   6.161117
# 57113                                   6.127338
# 60747                                   6.153575

# %% [markdown]
# Vemos que de todos los datos, hay uno solo en donde is_canceled es true, los dejamos en el dataset.

# %% [markdown]
# #### **adults y adr**
# Realizamos la matriz de Mahalanobis y mostramos su boxplot.

# %%
boxplot_mahalanobis_entre('adults', 'adr')
# Out:
# mahala_dist_adults_adr

# %% [markdown]
# Ahora veamos un dispersograma con un umbral para outliers con distancia de Mahalanobis mayor a 10.

# %%
es_outlier = (df_hotel_mahalanobis['mahala_dist_adults_adr'] > 10)
sns.scatterplot(x=df_hotel['adults'],y=df_hotel['adr'], hue=es_outlier)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0, title="Outlier")
plt.title('Dispersograma adults vs adr')
plt.show()

# %% [markdown]
# Observemos ese caso de outlier.

# %%
df_superiores = df_hotel_mahalanobis[df_hotel_mahalanobis['mahala_dist_adults_adr']>10]
df_superiores
# Out:
#               hotel  lead_time  arrival_date_year arrival_date_month  \
# 11745  Resort Hotel        334               2015            October
# 35253  Resort Hotel        334               2015            October
#
#        arrival_date_day_of_month  stays_in_weekend_nights  \
# 11745                         12                        2
# 35253                         12                        2
#
#        stays_in_week_nights  adults  children  babies meal country  \
# 11745                     5      20         0       0   BB     PRT
# 35253                     5      10         0       0   BB     PRT
#
#       market_segment distribution_channel  is_repeated_guest  \
# 11745         Direct               Direct              False
# 35253         Direct               Direct              False
#
#        previous_cancellations  previous_bookings_not_canceled  \
# 11745                       0                               0
# 35253                       0                               0
#
#       reserved_room_type assigned_room_type  booking_changes deposit_type  \
# 11745                  D                  D                0   No Deposit
# 35253                  E                  E                0   No Deposit
#
#            agent      company  days_in_waiting_list customer_type   adr  \
# 11745  not agent  not company                     0         Group  95.0
# 35253  not agent  not company                     0         Group  95.0
#
#        required_car_parking_spaces  total_of_special_requests  is_canceled  \
# 11745                            0                          0         True
# 35253                            0                          0         True
#
#        mahala_dist_total_of_special_requests_adr  mahala_dist_adults_adr
# 11745                                   2.639539               35.605225
# 35253                                   2.639539               14.325613

# %% [markdown]
# Vamos a eliminar el caso que se sale más de la media, y el otro lo dejaremos.

# %%
eliminar(df_hotel_mahalanobis[df_hotel_mahalanobis['mahala_dist_adults_adr']>20])

# %% [markdown]
# #### **required_car_parking_spaces y total_of_special_requests**

# %% [markdown]
# Observemos un boxplot de la distancia de Mahalanobis entre las variables.

# %%
boxplot_mahalanobis_entre('required_car_parking_spaces', 'total_of_special_requests')
# Out:
# mahala_dist_required_car_parking_spaces_total_of_special_requests

# %% [markdown]
# Centremonos en los casos en donde la distancia sea mayor que 8, a través del siguente diagrama de dispersión.

# %%
es_outlier = (df_hotel_mahalanobis['mahala_dist_required_car_parking_spaces_total_of_special_requests'] > 8)
sns.scatterplot(x=df_hotel['required_car_parking_spaces'],y=df_hotel['total_of_special_requests'], hue=es_outlier)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0, title="Outlier")
plt.title('Dispersograma required_car_parking_spaces vs total_of_special_requests')
plt.show()

# %%
df_superiores = df_hotel_mahalanobis[es_outlier]
df_superiores
# Out:
#               hotel  lead_time  arrival_date_year arrival_date_month  \
# 619      City Hotel          1               2017               July
# 2155   Resort Hotel        223               2016                May
# 9614   Resort Hotel         32               2016             August
# 10975  Resort Hotel          0               2017            January
# 11735  Resort Hotel         36               2016              March
# 13615  Resort Hotel        205               2017               June
# 14288  Resort Hotel         44               2015               July
# 21949  Resort Hotel        225               2016                May
# 38385  Resort Hotel          5               2017           February
# 42360  Resort Hotel        169               2016              March
# 50947  Resort Hotel        180               2016             August
# 53604  Resort Hotel         37               2017                May
# 55160  Resort Hotel         15               2017            January
#
#        arrival_date_day_of_month  stays_in_weekend_nights  \
# 619                           13                        0
# 2155                          24                        1
# 9614                          30                        0
# 10975                         29                        1
# 11735                         10                        2
# 13615                         26                        3
# 14288                          5                        2
# 21949                         26                        2
# 38385                         28                        1
# 42360                         31                        1
# 50947                          1                        1
# 53604                         28                        2
# 55160                          6                        0
#
#        stays_in_week_nights  adults  children  babies meal country  \
# 619                       1       3         0       1   BB     PRT
# 2155                      5       2         0       0   BB     GBR
# 9614                      1       3         1       0   BB     BEL
# 10975                     0       2         2       0   BB     GBR
# 11735                     5       2         0       0   BB     POL
# 13615                    10       2         0       0   BB     PRT
# 14288                     0       3         0       0   HB     PRT
# 21949                     3       2         0       0   BB     GBR
# 38385                     5       2         0       0   BB     NLD
# 42360                     3       2         0       0   BB     NLD
# 50947                     4       2         1       0   HB     PRT
# 53604                     1       2         0       0   BB     GBR
# 55160                     2       2         0       0   HB     ESP
#
#       market_segment distribution_channel  is_repeated_guest  \
# 619           Direct               Direct              False
# 2155          Groups               Direct              False
# 9614       Online TA                TA/TO              False
# 10975         Direct                TA/TO               True
# 11735      Online TA                TA/TO              False
# 13615         Direct               Direct              False
# 14288      Online TA                TA/TO              False
# 21949         Groups               Direct              False
# 38385         Groups            Corporate              False
# 42360         Groups               Direct              False
# 50947      Online TA                TA/TO              False
# 53604      Online TA                TA/TO              False
# 55160      Online TA                TA/TO              False
#
#        previous_cancellations  previous_bookings_not_canceled  \
# 619                         0                               0
# 2155                        0                               0
# 9614                        0                               0
# 10975                       0                               0
# 11735                       0                               0
# 13615                       0                               0
# 14288                       0                               0
# 21949                       0                               0
# 38385                       0                               0
# 42360                       0                               0
# 50947                       0                               0
# 53604                       0                               0
# 55160                       0                               0
#
#       reserved_room_type assigned_room_type  booking_changes deposit_type  \
# 619                    F                  F                0   No Deposit
# 2155                   A                  A                4   No Deposit
# 9614                   H                  H                0   No Deposit
# 10975                  G                  G                0   No Deposit
# 11735                  A                  A                0   No Deposit
# 13615                  A                  A                2   No Deposit
# 14288                  G                  G                3   No Deposit
# 21949                  A                  A                2   Refundable
# 38385                  A                  A                1   No Deposit
# 42360                  A                  A                0   Refundable
# 50947                  A                  A                3   No Deposit
# 53604                  A                  C                0   No Deposit
# 55160                  A                  A                0   No Deposit
#
#            agent      company  days_in_waiting_list    customer_type     adr  \
# 619         14.0  not company                     0        Transient  283.00
# 2155   not agent        223.0                     0  Transient-Party   52.00
# 9614       240.0  not company                     0        Transient  274.00
# 10975  not agent  not company                     0  Transient-Party   85.00
# 11735      240.0  not company                     0        Transient   59.14
# 13615      250.0  not company                     0        Transient  111.00
# 14288      240.0  not company                     0        Transient  225.00
# 21949  not agent        223.0                     0  Transient-Party   80.00
# 38385  not agent        223.0                     0  Transient-Party   47.50
# 42360  not agent        223.0                     0  Transient-Party   78.00
# 50947      241.0  not company                     0        Transient  187.80
# 53604      242.0  not company                     0        Transient  104.00
# 55160      314.0  not company                     0  Transient-Party   80.40
#
#        required_car_parking_spaces  total_of_special_requests  is_canceled  \
# 619                              2                          1        False
# 2155                             2                          0        False
# 9614                             2                          1        False
# 10975                            2                          0        False
# 11735                            2                          2        False
# 13615                            3                          0        False
# 14288                            2                          0        False
# 21949                            2                          0        False
# 38385                            2                          0        False
# 42360                            2                          0        False
# 50947                            2                          3        False
# 53604                            2                          1        False
# 55160                            2                          1        False
#
#        mahala_dist_total_of_special_requests_adr  mahala_dist_adults_adr  \
# 619                                     1.717571                2.618207
# 2155                                    3.504891                4.399463
# 9614                                    1.515403                2.452033
# 10975                                   2.834951                4.003425
# 11735                                   3.764894                4.305623
# 13615                                   2.337888                3.769630
# 14288                                   1.502160                1.707642
# 21949                                   2.934236                4.056870
# 38385                                   3.598431                4.460671
# 42360                                   2.974211                4.078953
# 50947                                   2.680649                3.603244
# 53604                                   2.308015                3.824869
# 55160                                   2.838369                4.052502
#
#        mahala_dist_required_car_parking_spaces_total_of_special_requests
# 619                                             8.788453
# 2155                                            9.007988
# 9614                                            8.788453
# 10975                                           9.007988
# 11735                                           8.757425
# 13615                                          13.591974
# 14288                                           9.007988
# 21949                                           9.007988
# 38385                                           9.007988
# 42360                                           9.007988
# 50947                                           8.916871
# 53604                                           8.788453
# 55160                                           8.788453

# %% [markdown]
# Vemos que por más que son outliers, es importante dejarlos, ya que son relevantes para nuestro objetivo. En totos los casos is_canceled es false. Aún así vamos a observar caso más alejado, en donde la distancia es casi 14.

# %%
df_superiores = df_hotel_mahalanobis[df_hotel_mahalanobis['mahala_dist_required_car_parking_spaces_total_of_special_requests']>13]
df_superiores
# Out:
#               hotel  lead_time  arrival_date_year arrival_date_month  \
# 13615  Resort Hotel        205               2017               June
#
#        arrival_date_day_of_month  stays_in_weekend_nights  \
# 13615                         26                        3
#
#        stays_in_week_nights  adults  children  babies meal country  \
# 13615                    10       2         0       0   BB     PRT
#
#       market_segment distribution_channel  is_repeated_guest  \
# 13615         Direct               Direct              False
#
#        previous_cancellations  previous_bookings_not_canceled  \
# 13615                       0                               0
#
#       reserved_room_type assigned_room_type  booking_changes deposit_type  \
# 13615                  A                  A                2   No Deposit
#
#        agent      company  days_in_waiting_list customer_type    adr  \
# 13615  250.0  not company                     0     Transient  111.0
#
#        required_car_parking_spaces  total_of_special_requests  is_canceled  \
# 13615                            3                          0        False
#
#        mahala_dist_total_of_special_requests_adr  mahala_dist_adults_adr  \
# 13615                                   2.337888                 3.76963
#
#        mahala_dist_required_car_parking_spaces_total_of_special_requests
# 13615                                          13.591974

# %% [markdown]
# Como se trata de un caso que se aleja demasiado del comportamiento típico, decidimos eliminarlo.

# %%
eliminar(df_hotel_mahalanobis[df_hotel_mahalanobis['mahala_dist_adults_adr']>20])

# %% [markdown]
# #### **children y adr**

# %% [markdown]
# Veamos la boxplot de la matriz de Mahalanobis.

# %%
boxplot_mahalanobis_entre('children', 'adr')
# Out:
# mahala_dist_children_adr

# %% [markdown]
# Veamos un dispersograma con umbral de 8 para la distancia de Mahalanobis.

# %%
es_outlier = (df_hotel_mahalanobis['mahala_dist_children_adr'] > 8)
sns.scatterplot(x=df_hotel['children'],y=df_hotel['adr'], hue=es_outlier)
plt.legend(bbox_to_anchor=(1, 1), loc='upper left', borderaxespad=0, title="Outlier")
plt.title('Dispersograma adults vs adr')
plt.xticks([i for i in range(0, 5, 1)])
plt.show()

# %% [markdown]
# Nos vamos a centrar en esos datos.

# %%
df_superiores = df_hotel_mahalanobis[df_hotel_mahalanobis['mahala_dist_children_adr']>8]
df_superiores
# Out:
#               hotel  lead_time  arrival_date_year arrival_date_month  \
# 12356    City Hotel        159               2017                May
# 23514  Resort Hotel          8               2016           November
# 28170  Resort Hotel        266               2016               June
# 33185    City Hotel          0               2016            January
# 50024  Resort Hotel          2               2016                May
# 51964    City Hotel        197               2016           December
# 53049    City Hotel        227               2016               July
# 58255    City Hotel         59               2016               July
#
#        arrival_date_day_of_month  stays_in_weekend_nights  \
# 12356                         24                        0
# 23514                         25                        0
# 28170                         28                        2
# 33185                          8                        0
# 50024                         15                        2
# 51964                         21                        1
# 53049                         28                        2
# 58255                         24                        2
#
#        stays_in_week_nights  adults  children  babies meal country  \
# 12356                     4       0         3       0   HB     FRA
# 23514                     2       2         3       0   BB     PRT
# 28170                     8       2         3       0   BB     PRT
# 33185                     2       0         3       0   BB     PRT
# 50024                     3       2         3       0   BB     PRT
# 51964                     4       0         3       0   HB     FRA
# 53049                     4       2         3       0   BB     FRA
# 58255                     4       0         3       0   BB     PRT
#
#       market_segment distribution_channel  is_repeated_guest  \
# 12356      Online TA                TA/TO              False
# 23514         Direct               Direct               True
# 28170      Online TA                TA/TO              False
# 33185         Direct               Direct              False
# 50024      Corporate            Corporate              False
# 51964  Offline TA/TO                TA/TO              False
# 53049         Direct               Direct              False
# 58255         Direct               Direct              False
#
#        previous_cancellations  previous_bookings_not_canceled  \
# 12356                       0                               0
# 23514                       0                               1
# 28170                       0                               0
# 33185                       0                               0
# 50024                       0                               0
# 51964                       0                               0
# 53049                       0                               0
# 58255                       0                               0
#
#       reserved_room_type assigned_room_type  booking_changes deposit_type  \
# 12356                  A                  A                5   No Deposit
# 23514                  H                  H                0   No Deposit
# 28170                  H                  H                0   No Deposit
# 33185                  B                  B                1   No Deposit
# 50024                  H                  H                1   No Deposit
# 51964                  A                  A                7   No Deposit
# 53049                  B                  B                2   No Deposit
# 58255                  B                  B                0   No Deposit
#
#            agent      company  days_in_waiting_list    customer_type     adr  \
# 12356       83.0  not company                     0        Transient  129.60
# 23514      250.0  not company                     0        Transient   88.00
# 28170      240.0  not company                     0        Transient  151.80
# 33185  not agent  not company                     0  Transient-Party    9.00
# 50024  not agent        110.0                     0        Transient  140.00
# 51964        3.0  not company                     0  Transient-Party   43.80
# 53049       14.0  not company                     0        Transient   79.26
# 58255  not agent  not company                     0        Transient    9.00
#
#        required_car_parking_spaces  total_of_special_requests  is_canceled  \
# 12356                            0                          0        False
# 23514                            0                          0        False
# 28170                            0                          0         True
# 33185                            0                          1        False
# 50024                            1                          3        False
# 51964                            0                          0        False
# 53049                            0                          0         True
# 58255                            0                          2         True
#
#        mahala_dist_total_of_special_requests_adr  mahala_dist_adults_adr  \
# 12356                                   2.011338                7.701286
# 23514                                   2.775861                3.972597
# 28170                                   1.675719                3.576025
# 33185                                   4.443131                8.070681
# 50024                                   3.208165                3.608291
# 51964                                   3.675644                7.866927
# 53049                                   2.949010                4.064995
# 58255                                   4.844092                8.070681
#
#        mahala_dist_required_car_parking_spaces_total_of_special_requests  \
# 12356                                           1.391777
# 23514                                           1.391777
# 28170                                           1.391777
# 33185                                           0.453023
# 50024                                           4.673155
# 51964                                           1.391777
# 53049                                           1.391777
# 58255                                           1.354969
#
#        mahala_dist_children_adr
# 12356                  8.300271
# 23514                  8.865789
# 28170                  8.031337
# 33185                 10.116377
# 50024                  8.171206
# 51964                  9.540845
# 53049                  8.993702
# 58255                 10.116377

# %% [markdown]
# Al ser una cantidad muy pequeña de datos, decidimos eliminarlos.

# %%
eliminar(df_superiores)

# %% [markdown]
# #### **stays_in_weekend_nights y stays_in_week_nights**

# %%
boxplot_mahalanobis_entre('stays_in_weekend_nights', 'stays_in_week_nights')
# Out:
# mahala_dist_stays_in_weekend_nights_stays_in_week_nights

# %% [markdown]
# También mostramos un diagrama de dispersión.

# %%
plt.scatter(df_hotel['stays_in_week_nights'], df_hotel['stays_in_weekend_nights'], alpha = 0.5)
plt.xlabel('stays_in_week_nights')
plt.ylabel('stays_in_weekend_nights')
plt.show()

# %% [markdown]
# Observamos que existen casos en donde las personas van unicamente a pasar el día, (ambos valores son cero) sigue siendo un dato válido.
#
# Tambien vemos que el diagrama de dispersión tiene un comportamiento válido, ya que es creciente, (a más días de fin de semana, también más días de semana).

# %%
df_superiores = df_hotel_mahalanobis[df_hotel_mahalanobis['mahala_dist_stays_in_weekend_nights_stays_in_week_nights']>12]
df_superiores
# Out:
#               hotel  lead_time  arrival_date_year arrival_date_month  \
# 43389  Resort Hotel        242               2017           February
# 54046  Resort Hotel        122               2016            January
# 57059  Resort Hotel        214               2016            January
#
#        arrival_date_day_of_month  stays_in_weekend_nights  \
# 43389                         17                       12
# 54046                         12                       12
# 57059                         26                       12
#
#        stays_in_week_nights  adults  children  babies meal country  \
# 43389                    30       2         0       0   BB     DEU
# 54046                    30       2         0       0   BB     PRT
# 57059                    30       2         0       0   BB     GBR
#
#       market_segment distribution_channel  is_repeated_guest  \
# 43389  Offline TA/TO                TA/TO              False
# 54046  Offline TA/TO                TA/TO              False
# 57059  Offline TA/TO                TA/TO              False
#
#        previous_cancellations  previous_bookings_not_canceled  \
# 43389                       0                               0
# 54046                       0                               0
# 57059                       0                               0
#
#       reserved_room_type assigned_room_type  booking_changes deposit_type  \
# 43389                  D                  D                0   No Deposit
# 54046                  A                  A                0   No Deposit
# 57059                  D                  D                0   No Deposit
#
#       agent      company  days_in_waiting_list customer_type    adr  \
# 43389  75.0  not company                     0     Transient  35.70
# 54046   8.0  not company                     0     Transient  22.11
# 57059   8.0  not company                     0     Transient  31.45
#
#        required_car_parking_spaces  total_of_special_requests  is_canceled  \
# 43389                            0                          1        False
# 54046                            0                          0         True
# 57059                            0                          0        False
#
#        mahala_dist_total_of_special_requests_adr  mahala_dist_adults_adr  \
# 43389                                   3.843008                4.628234
# 54046                                   4.132934                4.832756
# 57059                                   3.935128                4.690933
#
#        mahala_dist_required_car_parking_spaces_total_of_special_requests  \
# 43389                                           0.453023
# 54046                                           1.391777
# 57059                                           1.391777
#
#        mahala_dist_children_adr  \
# 43389                  3.885057
# 54046                  4.203029
# 57059                  3.984451
#
#        mahala_dist_stays_in_weekend_nights_stays_in_week_nights
# 43389                                          14.004355
# 54046                                          14.004355
# 57059                                          14.004355

# %% [markdown]
# Creemos conveniente eliminarlos, ya que se alejan del comportamiento común.

# %%
eliminar(df_superiores)

# %% [markdown]
# #### **previous_cancellations y previous_bookings_not_canceled**

# %% [markdown]
# Veamos el boxplot con la distancia de Mahalanobis.

# %%
boxplot_mahalanobis_entre('previous_cancellations', 'previous_bookings_not_canceled')
# Out:
# mahala_dist_previous_cancellations_previous_bookings_not_canceled

# %% [markdown]
# Hay muchos outliers, veamos los casos con un umbral de 40.

# %%
df_superiores = df_hotel_mahalanobis[df_hotel_mahalanobis['mahala_dist_previous_cancellations_previous_bookings_not_canceled']>30]
df_superiores
# Out:
#             hotel  lead_time  arrival_date_year arrival_date_month  \
# 8096   City Hotel          0               2017            January
# 10075  City Hotel          4               2017                May
# 19431  City Hotel          8               2016           December
# 20140  City Hotel          4               2017               July
# 23899  City Hotel          6               2016           December
# 24471  City Hotel          1               2017            January
# 26880  City Hotel          1               2016          September
# 28188  City Hotel          7               2016           November
# 28427  City Hotel          7               2016           December
# 32200  City Hotel          5               2017            January
# 34966  City Hotel          5               2017                May
# 36771  City Hotel          4               2016            October
# 38974  City Hotel          5               2017               July
# 55876  City Hotel          6               2017                May
#
#        arrival_date_day_of_month  stays_in_weekend_nights  \
# 8096                           2                        1
# 10075                          2                        0
# 19431                         28                        0
# 20140                         16                        1
# 23899                          8                        0
# 24471                         31                        0
# 26880                          6                        0
# 28188                          2                        2
# 28427                         14                        0
# 32200                         10                        0
# 34966                          8                        1
# 36771                         24                        1
# 38974                         11                        0
# 55876                         22                        1
#
#        stays_in_week_nights  adults  children  babies meal country  \
# 8096                      2       1         0       0   BB     PRT
# 10075                     2       1         0       0   BB     PRT
# 19431                     2       1         0       0   BB     PRT
# 20140                     0       1         0       0   BB     PRT
# 23899                     1       1         0       0   BB     PRT
# 24471                     3       1         0       0   BB     PRT
# 26880                     3       1         0       0   BB     PRT
# 28188                     6       1         0       0   BB     PRT
# 28427                     2       1         0       0   BB     PRT
# 32200                     3       1         0       0   BB     PRT
# 34966                     2       1         0       0   BB     PRT
# 36771                     2       1         0       0   BB     PRT
# 38974                     2       1         0       0   BB     PRT
# 55876                     1       1         0       0   BB     PRT
#
#       market_segment distribution_channel  is_repeated_guest  \
# 8096       Corporate            Corporate               True
# 10075      Corporate            Corporate               True
# 19431      Corporate            Corporate               True
# 20140      Corporate            Corporate               True
# 23899      Corporate            Corporate               True
# 24471      Corporate            Corporate               True
# 26880      Corporate            Corporate               True
# 28188      Corporate            Corporate               True
# 28427      Corporate            Corporate               True
# 32200      Corporate            Corporate               True
# 34966      Corporate            Corporate               True
# 36771      Corporate            Corporate               True
# 38974      Corporate            Corporate               True
# 55876      Corporate            Corporate               True
#
#        previous_cancellations  previous_bookings_not_canceled  \
# 8096                        6                              58
# 10075                       6                              62
# 19431                       6                              58
# 20140                       6                              70
# 23899                       5                              55
# 24471                       6                              61
# 26880                       3                              43
# 28188                       5                              50
# 28427                       5                              56
# 32200                       6                              59
# 34966                       6                              63
# 36771                       5                              49
# 38974                       6                              69
# 55876                       6                              64
#
#       reserved_room_type assigned_room_type  booking_changes deposit_type  \
# 8096                   A                  A                0   No Deposit
# 10075                  A                  A                1   No Deposit
# 19431                  A                  A                1   No Deposit
# 20140                  A                  A                0   No Deposit
# 23899                  A                  A                0   No Deposit
# 24471                  A                  A                0   No Deposit
# 26880                  A                  B                0   No Deposit
# 28188                  A                  A                0   No Deposit
# 28427                  A                  A                3   No Deposit
# 32200                  A                  A                0   No Deposit
# 34966                  A                  A                0   No Deposit
# 36771                  A                  A                0   No Deposit
# 38974                  A                  A                0   No Deposit
# 55876                  A                  A                1   No Deposit
#
#            agent      company  days_in_waiting_list    customer_type   adr  \
# 8096   not agent         40.0                     0        Transient  65.0
# 10075  not agent         40.0                     0        Transient  65.0
# 19431  not agent         40.0                     0        Transient  65.0
# 20140  not agent         40.0                     0        Transient  65.0
# 23899  not agent         40.0                     0        Transient  67.0
# 24471  not agent         40.0                     0        Transient  65.0
# 26880  not agent         40.0                     0        Transient  67.0
# 28188       40.0  not company                     0  Transient-Party  65.0
# 28427  not agent         40.0                     0        Transient  67.0
# 32200  not agent         40.0                     0        Transient  65.0
# 34966  not agent         40.0                     0        Transient  65.0
# 36771  not agent         40.0                     0        Transient  65.0
# 38974  not agent         40.0                     0        Transient  65.0
# 55876  not agent         40.0                     0        Transient  65.0
#
#        required_car_parking_spaces  total_of_special_requests  is_canceled  \
# 8096                             0                          0        False
# 10075                            0                          1        False
# 19431                            0                          2         True
# 20140                            0                          1        False
# 23899                            0                          2        False
# 24471                            0                          1        False
# 26880                            1                          0        False
# 28188                            0                          0        False
# 28427                            1                          2        False
# 32200                            0                          2        False
# 34966                            0                          1        False
# 36771                            0                          2        False
# 38974                            0                          2        False
# 55876                            0                          1        False
#
#        mahala_dist_total_of_special_requests_adr  mahala_dist_adults_adr  \
# 8096                                    3.237236                5.885314
# 10075                                   3.184474                5.885314
# 19431                                   3.640660                5.885314
# 20140                                   3.184474                5.885314
# 23899                                   3.598381                5.872111
# 24471                                   3.184474                5.885314
# 26880                                   3.196440                5.872111
# 28188                                   3.237236                5.885314
# 28427                                   3.598381                5.872111
# 32200                                   3.640660                5.885314
# 34966                                   3.184474                5.885314
# 36771                                   3.640660                5.885314
# 38974                                   3.640660                5.885314
# 55876                                   3.184474                5.885314
#
#        mahala_dist_required_car_parking_spaces_total_of_special_requests  \
# 8096                                            1.391777
# 10075                                           0.453023
# 19431                                           1.354969
# 20140                                           0.453023
# 23899                                           1.354969
# 24471                                           0.453023
# 26880                                           4.495435
# 28188                                           1.391777
# 28427                                           4.234703
# 32200                                           1.354969
# 34966                                           0.453023
# 36771                                           1.354969
# 38974                                           1.354969
# 55876                                           0.453023
#
#        mahala_dist_children_adr  \
# 8096                   3.201321
# 10075                  3.201321
# 19431                  3.201321
# 20140                  3.201321
# 23899                  3.154770
# 24471                  3.201321
# 26880                  3.154770
# 28188                  3.201321
# 28427                  3.154770
# 32200                  3.201321
# 34966                  3.201321
# 36771                  3.201321
# 38974                  3.201321
# 55876                  3.201321
#
#        mahala_dist_stays_in_weekend_nights_stays_in_week_nights  \
# 8096                                            1.611130
# 10075                                           2.032835
# 19431                                           2.032835
# 20140                                           2.721003
# 23899                                           2.342006
# 24471                                           1.876656
# 26880                                           1.876656
# 28188                                           0.535597
# 28427                                           2.032835
# 32200                                           1.876656
# 34966                                           1.611130
# 36771                                           1.611130
# 38974                                           2.032835
# 55876                                           2.151465
#
#        mahala_dist_previous_cancellations_previous_bookings_not_canceled
# 8096                                           41.534010
# 10075                                          44.408321
# 19431                                          41.534010
# 20140                                          50.166087
# 23899                                          39.378484
# 24471                                          43.689415
# 26880                                          30.777150
# 28188                                          35.782092
# 28427                                          40.098401
# 32200                                          42.252248
# 34966                                          45.127428
# 36771                                          35.063545
# 38974                                          49.445807
# 55876                                          45.846727

# %% [markdown]
# Vemos que en todos los casos, excepto uno is_canceled es false, por lo que creemos conveniente no eliminarlos.

# %% [markdown]
# #### **lead_time y days_in_waiting_list**

# %% [markdown]
# Veamos los outliers entre lead_time y days_in_waiting_list

# %%
boxplot_mahalanobis_entre('lead_time', 'days_in_waiting_list')
# Out:
# mahala_dist_lead_time_days_in_waiting_list

# %%
df_superiores = df_hotel_mahalanobis[df_hotel_mahalanobis['mahala_dist_lead_time_days_in_waiting_list']>15]
print("Total de casos:",df_superiores.shape[0], "de los cuales son True: ",df_superiores[df_superiores['is_canceled'] == True].shape[0])
# Out:
# Total de casos: 45 de los cuales son True:  38

# %% [markdown]
# Ya que hay muchos casos en donde is_canceled es true, no vamos a hacer nada con estos.

# %% [markdown]
# #### **lead_time y adults**

# %% [markdown]
# Veamos los outliers entre lead_time y adults

# %%
boxplot_mahalanobis_entre('lead_time', 'adults')
# Out:
# mahala_dist_lead_time_adults

# %% [markdown]
# Prestemos atención a los casos con superiores con un umbral del 8.

# %%
df_superiores = df_hotel_mahalanobis[df_hotel_mahalanobis['mahala_dist_lead_time_adults']>8]
df_superiores
# Out:
#               hotel  lead_time  arrival_date_year arrival_date_month  \
# 1769     City Hotel        340               2017               July
# 17665    City Hotel        351               2017               July
# 35248  Resort Hotel        334               2015            October
#
#        arrival_date_day_of_month  stays_in_weekend_nights  \
# 1769                           9                        2
# 17665                         27                        0
# 35248                         12                        2
#
#        stays_in_week_nights  adults  children  babies meal country  \
# 1769                      2       0         2       0   BB     NOR
# 17665                     3       0         2       0   BB     CHE
# 35248                     5      10         0       0   BB     PRT
#
#       market_segment distribution_channel  is_repeated_guest  \
# 1769       Online TA                TA/TO              False
# 17665      Online TA                TA/TO              False
# 35248         Direct               Direct              False
#
#        previous_cancellations  previous_bookings_not_canceled  \
# 1769                        0                               0
# 17665                       0                               0
# 35248                       0                               0
#
#       reserved_room_type assigned_room_type  booking_changes deposit_type  \
# 1769                   B                  B                0   No Deposit
# 17665                  B                  A                0   No Deposit
# 35248                  E                  E                0   No Deposit
#
#            agent      company  days_in_waiting_list customer_type    adr  \
# 1769         9.0  not company                     0     Transient  90.05
# 17665        9.0  not company                     0     Transient  90.05
# 35248  not agent  not company                     0         Group  95.00
#
#        required_car_parking_spaces  total_of_special_requests  is_canceled  \
# 1769                             0                          2         True
# 17665                            0                          1        False
# 35248                            0                          0         True
#
#        mahala_dist_total_of_special_requests_adr  mahala_dist_adults_adr  \
# 1769                                    3.116537                7.716152
# 17665                                   2.621501                7.716152
# 35248                                   2.639539               14.325613
#
#        mahala_dist_required_car_parking_spaces_total_of_special_requests  \
# 1769                                            1.354969
# 17665                                           0.453023
# 35248                                           1.391777
#
#        mahala_dist_children_adr  \
# 1769                   6.324093
# 17665                  6.324093
# 35248                  2.505552
#
#        mahala_dist_stays_in_weekend_nights_stays_in_week_nights  \
# 1769                                            1.929020
# 17665                                           1.876656
# 35248                                           0.180103
#
#        mahala_dist_previous_cancellations_previous_bookings_not_canceled  \
# 1769                                            0.265641
# 17665                                           0.265641
# 35248                                           0.265641
#
#        mahala_dist_lead_time_days_in_waiting_list  \
# 1769                                     1.135182
# 17665                                    1.232965
# 35248                                    1.082074
#
#        mahala_dist_lead_time_adults
# 1769                       8.030158
# 17665                      8.055220
# 35248                     13.126216

# %% [markdown]
# Únicamente son tres casos, por lo que decidimos eliminarlo.

# %%
eliminar(df_superiores)

# %% [markdown]
# Ahora miremos los inferiores a 1.

# %%
df_inferiores = df_hotel_mahalanobis[df_hotel_mahalanobis['mahala_dist_lead_time_adults']<1]
df_inferiores
# Out:
#               hotel  lead_time  arrival_date_year arrival_date_month  \
# 55119  Resort Hotel        318               2017               July
#
#        arrival_date_day_of_month  stays_in_weekend_nights  \
# 55119                         28                        1
#
#        stays_in_week_nights  adults  children  babies meal country  \
# 55119                     2       4         0       0   BB     PRT
#
#       market_segment distribution_channel  is_repeated_guest  \
# 55119      Online TA                TA/TO              False
#
#        previous_cancellations  previous_bookings_not_canceled  \
# 55119                       0                               0
#
#       reserved_room_type assigned_room_type  booking_changes deposit_type  \
# 55119                  C                  C                0   No Deposit
#
#        agent      company  days_in_waiting_list customer_type     adr  \
# 55119  147.0  not company                     0     Transient  139.68
#
#        required_car_parking_spaces  total_of_special_requests  is_canceled  \
# 55119                            0                          0         True
#
#        mahala_dist_total_of_special_requests_adr  mahala_dist_adults_adr  \
# 55119                                   1.849833                1.791821
#
#        mahala_dist_required_car_parking_spaces_total_of_special_requests  \
# 55119                                           1.391777
#
#        mahala_dist_children_adr  \
# 55119                  1.490492
#
#        mahala_dist_stays_in_weekend_nights_stays_in_week_nights  \
# 55119                                            1.61113
#
#        mahala_dist_previous_cancellations_previous_bookings_not_canceled  \
# 55119                                           0.265641
#
#        mahala_dist_lead_time_days_in_waiting_list  \
# 55119                                    0.941481
#
#        mahala_dist_lead_time_adults
# 55119                      0.965009

# %% [markdown]
# Es un solo caso, por lo que vamos a sacarlo.

# %%
eliminar(df_inferiores)

# %% [markdown]
# #### **lead_time y previous_cancellations**

# %% [markdown]
# Veamos los outliers entre lead_time y previous_cancellations

# %%
boxplot_mahalanobis_entre('lead_time', 'previous_cancellations')
# Out:
# mahala_dist_lead_time_previous_cancellations

# %% [markdown]
# Veamos los casos superiores con un umbral de 10.

# %%
df_superiores = df_hotel_mahalanobis[df_hotel_mahalanobis['mahala_dist_lead_time_previous_cancellations']>10]
print("Total de casos:",df_superiores.shape[0],"de los cuales is_canceled es true en:", df_superiores[df_superiores['is_canceled'] == True].shape[0])
# Out:
# Total de casos: 125 de los cuales is_canceled es true en: 116

# %% [markdown]
# Ya que en la gran mayoría de casos is_canceled es true, vamos a dejarlos.

# %% [markdown]
# #### **lead_time y previous_bookings_not_canceled**

# %% [markdown]
# Veamos los outliers entre lead_time y previous_bookings_not_canceled

# %%
boxplot_mahalanobis_entre('lead_time', 'previous_bookings_not_canceled')
# Out:
# mahala_dist_lead_time_previous_bookings_not_canceled

# %% [markdown]
# Veamos los casos superiores con un umbral de 40.

# %%
df_superiores = df_hotel_mahalanobis[df_hotel_mahalanobis['mahala_dist_lead_time_previous_bookings_not_canceled']>40]
df_superiores.head()
# Out:
#             hotel  lead_time  arrival_date_year arrival_date_month  \
# 8095   City Hotel          0               2017            January
# 10074  City Hotel          4               2017                May
# 19429  City Hotel          8               2016           December
# 20138  City Hotel          4               2017               July
# 24469  City Hotel          1               2017            January
#
#        arrival_date_day_of_month  stays_in_weekend_nights  \
# 8095                           2                        1
# 10074                          2                        0
# 19429                         28                        0
# 20138                         16                        1
# 24469                         31                        0
#
#        stays_in_week_nights  adults  children  babies meal country  \
# 8095                      2       1         0       0   BB     PRT
# 10074                     2       1         0       0   BB     PRT
# 19429                     2       1         0       0   BB     PRT
# 20138                     0       1         0       0   BB     PRT
# 24469                     3       1         0       0   BB     PRT
#
#       market_segment distribution_channel  is_repeated_guest  \
# 8095       Corporate            Corporate               True
# 10074      Corporate            Corporate               True
# 19429      Corporate            Corporate               True
# 20138      Corporate            Corporate               True
# 24469      Corporate            Corporate               True
#
#        previous_cancellations  previous_bookings_not_canceled  \
# 8095                        6                              58
# 10074                       6                              62
# 19429                       6                              58
# 20138                       6                              70
# 24469                       6                              61
#
#       reserved_room_type assigned_room_type  booking_changes deposit_type  \
# 8095                   A                  A                0   No Deposit
# 10074                  A                  A                1   No Deposit
# 19429                  A                  A                1   No Deposit
# 20138                  A                  A                0   No Deposit
# 24469                  A                  A                0   No Deposit
#
#            agent company  days_in_waiting_list customer_type   adr  \
# 8095   not agent    40.0                     0     Transient  65.0
# 10074  not agent    40.0                     0     Transient  65.0
# 19429  not agent    40.0                     0     Transient  65.0
# 20138  not agent    40.0                     0     Transient  65.0
# 24469  not agent    40.0                     0     Transient  65.0
#
#        required_car_parking_spaces  total_of_special_requests  is_canceled  \
# 8095                             0                          0        False
# 10074                            0                          1        False
# 19429                            0                          2         True
# 20138                            0                          1        False
# 24469                            0                          1        False
#
#        mahala_dist_total_of_special_requests_adr  mahala_dist_adults_adr  \
# 8095                                    3.237236                5.885314
# 10074                                   3.184474                5.885314
# 19429                                   3.640660                5.885314
# 20138                                   3.184474                5.885314
# 24469                                   3.184474                5.885314
#
#        mahala_dist_required_car_parking_spaces_total_of_special_requests  \
# 8095                                            1.391777
# 10074                                           0.453023
# 19429                                           1.354969
# 20138                                           0.453023
# 24469                                           0.453023
#
#        mahala_dist_children_adr  \
# 8095                   3.201321
# 10074                  3.201321
# 19429                  3.201321
# 20138                  3.201321
# 24469                  3.201321
#
#        mahala_dist_stays_in_weekend_nights_stays_in_week_nights  \
# 8095                                            1.611130
# 10074                                           2.032835
# 19429                                           2.032835
# 20138                                           2.721003
# 24469                                           1.876656
#
#        mahala_dist_previous_cancellations_previous_bookings_not_canceled  \
# 8095                                           41.534010
# 10074                                          44.408321
# 19429                                          41.534010
# 20138                                          50.166087
# 24469                                          43.689415
#
#        mahala_dist_lead_time_days_in_waiting_list  \
# 8095                                     2.034332
# 10074                                    1.998068
# 19429                                    1.961818
# 20138                                    1.998068
# 24469                                    2.025264
#
#        mahala_dist_lead_time_adults  \
# 8095                       5.859215
# 10074                      5.850796
# 19429                      5.842591
# 20138                      5.850796
# 24469                      5.857090
#
#        mahala_dist_lead_time_previous_cancellations  \
# 8095                                       6.342676
# 10074                                      6.327932
# 19429                                      6.313362
# 20138                                      6.327932
# 24469                                      6.338974
#
#        mahala_dist_lead_time_previous_bookings_not_canceled
# 8095                                           41.537614
# 10074                                          44.416749
# 19429                                          41.538920
# 20138                                          50.174817
# 24469                                          43.696540

# %% [markdown]
# Vamos a eliminar estos casos, ya que están muy lejos de la media.

# %%
eliminar(df_superiores)

# %% [markdown]
# #### **adr y previous_bookings_not_canceled**

# %% [markdown]
# Veamos los outliers entre lead_time y previous_bookings_not_canceled

# %%
boxplot_mahalanobis_entre('adr', 'previous_bookings_not_canceled')
# Out:
# mahala_dist_adr_previous_bookings_not_canceled

# %% [markdown]
# Veamos los casos superiores con un umbral de 40.

# %%
df_superiores = df_hotel_mahalanobis[df_hotel_mahalanobis['mahala_dist_adr_previous_bookings_not_canceled']>40]
df_superiores
# Out:
#             hotel  lead_time  arrival_date_year arrival_date_month  \
# 23893  City Hotel          6               2016           December
# 28181  City Hotel          7               2016           November
# 36760  City Hotel          4               2016            October
#
#        arrival_date_day_of_month  stays_in_weekend_nights  \
# 23893                          8                        0
# 28181                          2                        2
# 36760                         24                        1
#
#        stays_in_week_nights  adults  children  babies meal country  \
# 23893                     1       1         0       0   BB     PRT
# 28181                     6       1         0       0   BB     PRT
# 36760                     2       1         0       0   BB     PRT
#
#       market_segment distribution_channel  is_repeated_guest  \
# 23893      Corporate            Corporate               True
# 28181      Corporate            Corporate               True
# 36760      Corporate            Corporate               True
#
#        previous_cancellations  previous_bookings_not_canceled  \
# 23893                       5                              55
# 28181                       5                              50
# 36760                       5                              49
#
#       reserved_room_type assigned_room_type  booking_changes deposit_type  \
# 23893                  A                  A                0   No Deposit
# 28181                  A                  A                0   No Deposit
# 36760                  A                  A                0   No Deposit
#
#            agent      company  days_in_waiting_list    customer_type   adr  \
# 23893  not agent         40.0                     0        Transient  67.0
# 28181       40.0  not company                     0  Transient-Party  65.0
# 36760  not agent         40.0                     0        Transient  65.0
#
#        required_car_parking_spaces  total_of_special_requests  is_canceled  \
# 23893                            0                          2        False
# 28181                            0                          0        False
# 36760                            0                          2        False
#
#        mahala_dist_total_of_special_requests_adr  mahala_dist_adults_adr  \
# 23893                                   3.598381                5.872111
# 28181                                   3.237236                5.885314
# 36760                                   3.640660                5.885314
#
#        mahala_dist_required_car_parking_spaces_total_of_special_requests  \
# 23893                                           1.354969
# 28181                                           1.391777
# 36760                                           1.354969
#
#        mahala_dist_children_adr  \
# 23893                  3.154770
# 28181                  3.201321
# 36760                  3.201321
#
#        mahala_dist_stays_in_weekend_nights_stays_in_week_nights  \
# 23893                                           2.342006
# 28181                                           0.535597
# 36760                                           1.611130
#
#        mahala_dist_previous_cancellations_previous_bookings_not_canceled  \
# 23893                                          39.378484
# 28181                                          35.782092
# 36760                                          35.063545
#
#        mahala_dist_lead_time_days_in_waiting_list  \
# 23893                                    1.979941
# 28181                                    1.970879
# 36760                                    1.998068
#
#        mahala_dist_lead_time_adults  \
# 23893                      5.846667
# 28181                      5.844622
# 36760                      5.850796
#
#        mahala_dist_lead_time_previous_cancellations  \
# 23893                                      5.372808
# 28181                                      5.368690
# 36760                                      5.381081
#
#        mahala_dist_lead_time_previous_bookings_not_canceled  \
# 23893                                          39.379960
# 28181                                          35.783051
# 36760                                          35.063504
#
#        mahala_dist_adr_previous_bookings_not_canceled
# 23893                                       47.885808
# 28181                                       43.519381
# 36760                                       42.646299

# %% [markdown]
# Vamos a eliminar estos casos, ya que son muy pocos.

# %%
eliminar(df_superiores)

# %% [markdown]
# #### **adr y lead_time**

# %% [markdown]
# Veamos los outliers entre lead_time y previous_bookings_not_canceled

# %%
boxplot_mahalanobis_entre('adr', 'lead_time')
# Out:
# mahala_dist_adr_lead_time

# %% [markdown]
# Veamos los casos superiores con un umbral de 5.

# %%
df_superiores = df_hotel_mahalanobis[df_hotel_mahalanobis['mahala_dist_adr_lead_time']>5]
print("Cantidad de casos con distancia de Mahalanobis superior a 5:",df_superiores.shape[0])
# Out:
# Cantidad de casos con distancia de Mahalanobis superior a 5: 87

# %% [markdown]
# Como son muchos casos, vamos a dejarlos.

# %%
df_inferiores = df_hotel_mahalanobis[df_hotel_mahalanobis['mahala_dist_adr_lead_time']<0.5]
print("Cantidad de casos con distancia de Mahalanobis inferior a 0.5:",df_inferiores.shape[0])
# Out:
# Cantidad de casos con distancia de Mahalanobis inferior a 0.5: 198

# %% [markdown]
# Por el mismo motivo anterior, no haremos nada con estos datos.

# %% [markdown]
# #### **adr y stays_in_week_nights**

# %% [markdown]
# Veamos los outliers entre lead_time y previous_bookings_not_canceled

# %%
boxplot_mahalanobis_entre('adr', 'stays_in_week_nights')
# Out:
# mahala_dist_adr_stays_in_week_nights

# %% [markdown]
# Veamos los casos superiores con un umbral de 10.

# %%
df_superiores = df_hotel_mahalanobis[df_hotel_mahalanobis['mahala_dist_adr_stays_in_week_nights']>10]
df_superiores
# Out:
#               hotel  lead_time  arrival_date_year arrival_date_month  \
# 9162   Resort Hotel         13               2016              April
# 14131    City Hotel         25               2015           November
# 30187  Resort Hotel         88               2017            January
# 47284    City Hotel          3               2016           November
# 60072  Resort Hotel        192               2017            January
#
#        arrival_date_day_of_month  stays_in_weekend_nights  \
# 9162                          25                        9
# 14131                         30                        9
# 30187                         24                       10
# 47284                         14                        9
# 60072                         14                       10
#
#        stays_in_week_nights  adults  children  babies meal country  \
# 9162                     24       2         0       0   BB     PRT
# 14131                    24       2         0       0   BB     PRT
# 30187                    25       2         0       0   BB     GBR
# 47284                    25       2         0       0   BB     PRT
# 60072                    25       2         0       0   BB     GBR
#
#       market_segment distribution_channel  is_repeated_guest  \
# 9162       Corporate            Corporate              False
# 14131         Direct               Direct              False
# 30187         Direct               Direct              False
# 47284      Corporate            Corporate              False
# 60072  Offline TA/TO                TA/TO              False
#
#        previous_cancellations  previous_bookings_not_canceled  \
# 9162                        0                               0
# 14131                       0                               0
# 30187                       0                               0
# 47284                       0                               0
# 60072                       0                               0
#
#       reserved_room_type assigned_room_type  booking_changes deposit_type  \
# 9162                   D                  D                0   No Deposit
# 14131                  A                  A                1   No Deposit
# 30187                  D                  D                0   No Deposit
# 47284                  A                  A                3   No Deposit
# 60072                  A                  D                0   No Deposit
#
#            agent      company  days_in_waiting_list customer_type    adr  \
# 9162   not agent        110.0                     0     Transient  77.00
# 14131  not agent  not company                     0     Transient  98.33
# 30187  not agent  not company                     0     Transient  41.47
# 47284  not agent        368.0                     0     Transient  93.00
# 60072        6.0  not company                     0     Transient  34.00
#
#        required_car_parking_spaces  total_of_special_requests  is_canceled  \
# 9162                             0                          0         True
# 14131                            0                          0         True
# 30187                            0                          1        False
# 47284                            0                          0        False
# 60072                            0                          0        False
#
#        mahala_dist_total_of_special_requests_adr  mahala_dist_adults_adr  \
# 9162                                    2.994251                4.090141
# 14131                                   2.575531                3.873900
# 30187                                   3.713322                4.545063
# 47284                                   2.678253                3.923354
# 60072                                   3.881345                4.653171
#
#        mahala_dist_required_car_parking_spaces_total_of_special_requests  \
# 9162                                            1.391777
# 14131                                           1.391777
# 30187                                           0.453023
# 47284                                           1.391777
# 60072                                           1.391777
#
#        mahala_dist_children_adr  \
# 9162                   2.922320
# 14131                  2.428751
# 30187                  3.750191
# 47284                  2.551731
# 60072                  3.924809
#
#        mahala_dist_stays_in_weekend_nights_stays_in_week_nights  \
# 9162                                           10.457907
# 14131                                          10.457907
# 30187                                          11.212821
# 47284                                          10.906728
# 60072                                          11.212821
#
#        mahala_dist_previous_cancellations_previous_bookings_not_canceled  \
# 9162                                            0.265641
# 14131                                           0.265641
# 30187                                           0.265641
# 47284                                           0.265641
# 60072                                           0.265641
#
#        mahala_dist_lead_time_days_in_waiting_list  \
# 9162                                     1.916525
# 14131                                    1.807925
# 30187                                    1.241494
# 47284                                    2.007133
# 60072                                    0.382523
#
#        mahala_dist_lead_time_adults  \
# 9162                       3.906532
# 14131                      3.865873
# 30187                      3.698174
# 47284                      3.942402
# 60072                      3.608096
#
#        mahala_dist_lead_time_previous_cancellations  \
# 9162                                       1.916778
# 14131                                      1.808766
# 30187                                      1.244114
# 47284                                      2.006856
# 60072                                      0.362277
#
#        mahala_dist_lead_time_previous_bookings_not_canceled  \
# 9162                                            1.937623
# 14131                                           1.829418
# 30187                                           1.262453
# 47284                                           2.027827
# 60072                                           0.349996
#
#        mahala_dist_adr_previous_bookings_not_canceled  \
# 9162                                         2.897016
# 14131                                        2.425988
# 30187                                        3.682223
# 47284                                        2.543653
# 60072                                        3.847369
#
#        mahala_dist_adr_lead_time  mahala_dist_adr_stays_in_week_nights
# 9162                    3.668239                             10.769971
# 14131                   3.199886                             10.623891
# 30187                   4.031972                             11.561792
# 47284                   3.430771                             11.180931
# 60072                   3.901413                             11.625262

# %% [markdown]
# Son pocos casos, los eliminaremos a continuación.

# %%
eliminar(df_superiores)

# %%
df_inferiores = df_hotel_mahalanobis[df_hotel_mahalanobis['mahala_dist_adr_stays_in_week_nights']<1]
print("Cantidad de casos con distancia de Mahalanobis inferior a 1:",df_inferiores.shape[0])
# Out:
# Cantidad de casos con distancia de Mahalanobis inferior a 1: 1528

# %% [markdown]
# Como son muchos datos, los dejaremos.

# %% [markdown]
# #### **adults y children con Isolation Forest**

# %% [markdown]
# Ahora veamos el análisis de adults y children pero utilizando Isolation Forest.

# %%
model = IsolationForest(n_estimators=100, max_samples='auto', contamination=0.05, random_state=42)
model.fit(df_hotel[['children', 'adults']])
anomaly_scores = model.decision_function(df_hotel[['children', 'adults']])
anomaly_labels = model.predict(df_hotel[['children', 'adults']])
df_hotel_mahalanobis['scores']=anomaly_scores
df_hotel_mahalanobis['outlier_label']=anomaly_labels
print("Outliers encontrados:",df_hotel_mahalanobis[df_hotel_mahalanobis.outlier_label==-1].shape[0])
# Out:
# Outliers encontrados: 2362

# %% [markdown]
# Ahora miremos el diagrama de dispersión.

# %%
color=[f"C{n+1}" for n in (df_hotel_mahalanobis['outlier_label'].values)]
sns.scatterplot(data=df_hotel_mahalanobis, x="children", y="adults", hue=color)
plt.title('Diagrama de Dispersión children vs adults')
plt.show()

# %% [markdown]
# Vemos que los casos, por más que sean outliers son posibles y no se alejan tanto de la media, por lo que decidimos dejarlos.

# %% [markdown]
# #### **adr y children con Isolation Forest**

# %% [markdown]
# Veamos los outliers con isolation forest.

# %%
df_hotel_isolation = df_hotel.copy()
model = IsolationForest(n_estimators=100, max_samples='auto', contamination=0.05, random_state=42)
model.fit(df_hotel[['children', 'adr']])
anomaly_scores = model.decision_function(df_hotel[['children', 'adr']])
anomaly_labels = model.predict(df_hotel[['children', 'adr']])
df_hotel_isolation['scores_AdrChildren']=anomaly_scores
df_hotel_isolation['outlier_label_scores_AdrChildren']=anomaly_labels
print("Outliers encontrados:",df_hotel_mahalanobis[df_hotel_mahalanobis.outlier_label==-1].shape[0])
# Out:
# Outliers encontrados: 2362

# %% [markdown]
# Ahora hacemos un diagrama de dispersión para mejor visualización de datos.

# %%
color = [f"C{n+1}" for n in df_hotel_isolation['outlier_label_scores_AdrChildren'].values]
sns.scatterplot(data=df_hotel_isolation, x="children", y="adr", hue=color)
plt.title('Diagrama de Dispersión children vs adr')
plt.grid(True)
plt.yticks(range(0, 400, 25))
plt.xticks(range(int(df_hotel_isolation['children'].min()), int(df_hotel_isolation['children'].max())+1, 1))
plt.show()

# %% [markdown]
# Vamos a filtrar a los outliers en donde adr es menor o igual a 25 y children es 2.

# %%
df_hotel_isolation[(df_hotel_isolation.adr <=25)& (df_hotel_isolation.children ==2)]
# Out:
#               hotel  lead_time  arrival_date_year arrival_date_month  \
# 4106     City Hotel        183               2017               July
# 9906     City Hotel          0               2017           February
# 9970     City Hotel          1               2015           December
# 10895    City Hotel         30               2016            January
# 13999    City Hotel        237               2016               July
# 14854    City Hotel         45               2016               June
# 19982    City Hotel          0               2016            October
# 21315    City Hotel          0               2016              April
# 30190    City Hotel        150               2016              March
# 30211    City Hotel          0               2017            January
# 32826    City Hotel        242               2016               July
# 39136  Resort Hotel         24               2017              March
# 41745    City Hotel         48               2015            October
# 50277  Resort Hotel        143               2016               July
# 58452    City Hotel        236               2016               July
# 60876    City Hotel         40               2016            January
#
#        arrival_date_day_of_month  stays_in_weekend_nights  \
# 4106                           7                        1
# 9906                           4                        0
# 9970                          23                        0
# 10895                          3                        1
# 13999                         24                        1
# 14854                         17                        2
# 19982                         27                        0
# 21315                          8                        0
# 30190                         24                        1
# 30211                         21                        0
# 32826                         29                        0
# 39136                         29                        2
# 41745                         19                        1
# 50277                         15                        2
# 58452                         28                        2
# 60876                         14                        0
#
#        stays_in_week_nights  adults  children  babies meal country  \
# 4106                      2       2         2       0   BB     DEU
# 9906                      1       0         2       0   BB     PRT
# 9970                      3       0         2       0   BB     DEU
# 10895                     0       0         2       0   BB     PRT
# 13999                     0       0         2       0   BB     BEL
# 14854                     2       0         2       0   BB     PRT
# 19982                     3       0         2       0   HB     FRA
# 21315                     1       0         2       0   BB     FRA
# 30190                     3       0         2       0   BB     PRT
# 30211                     1       0         2       0   BB     PRT
# 32826                     2       0         2       0   BB     BEL
# 39136                     5       2         2       0   BB     FRA
# 41745                     3       0         2       0   BB     PRT
# 50277                     7       2         2       1   BB     PRT
# 58452                     4       0         2       0   BB     NLD
# 60876                     3       0         2       0   BB     ESP
#
#       market_segment distribution_channel  is_repeated_guest  \
# 4106       Online TA                TA/TO              False
# 9906          Direct               Direct              False
# 9970       Online TA                TA/TO              False
# 10895      Online TA                TA/TO              False
# 13999         Direct               Direct              False
# 14854         Direct               Direct              False
# 19982      Online TA                TA/TO              False
# 21315      Online TA                TA/TO              False
# 30190      Online TA                TA/TO              False
# 30211         Direct               Direct               True
# 32826         Direct               Direct              False
# 39136         Direct               Direct              False
# 41745  Offline TA/TO                TA/TO              False
# 50277      Online TA                TA/TO              False
# 58452      Online TA                TA/TO              False
# 60876      Online TA                TA/TO              False
#
#        previous_cancellations  previous_bookings_not_canceled  \
# 4106                        0                               0
# 9906                        0                               0
# 9970                        0                               0
# 10895                       0                               0
# 13999                       0                               0
# 14854                       0                               0
# 19982                       0                               0
# 21315                       0                               0
# 30190                       1                               0
# 30211                       0                               1
# 32826                       0                               0
# 39136                       0                               0
# 41745                       0                               0
# 50277                       0                               0
# 58452                       0                               0
# 60876                       0                               0
#
#       reserved_room_type assigned_room_type  booking_changes deposit_type  \
# 4106                   F                  F                1   No Deposit
# 9906                   A                  A                1   No Deposit
# 9970                   B                  B                0   No Deposit
# 10895                  B                  B                2   No Deposit
# 13999                  B                  B                0   No Deposit
# 14854                  B                  B                0   No Deposit
# 19982                  F                  B                3   No Deposit
# 21315                  F                  B                0   No Deposit
# 30190                  B                  B                0   No Deposit
# 30211                  A                  A                1   No Deposit
# 32826                  B                  B                0   No Deposit
# 39136                  G                  G                1   No Deposit
# 41745                  B                  B                0   No Deposit
# 50277                  G                  G                0   No Deposit
# 58452                  B                  B                1   No Deposit
# 60876                  B                  B                0   No Deposit
#
#            agent      company  days_in_waiting_list    customer_type   adr  \
# 4106         9.0  not company                     0        Transient  18.0
# 9906   not agent  not company                     0  Transient-Party   6.0
# 9970         9.0  not company                     0  Transient-Party   6.0
# 10895        9.0  not company                     0  Transient-Party  15.0
# 13999       14.0  not company                     0  Transient-Party   6.0
# 14854  not agent  not company                     0  Transient-Party   6.0
# 19982        9.0  not company                     0        Transient  18.6
# 21315        9.0  not company                     0  Transient-Party   6.0
# 30190        8.0  not company                     0  Transient-Party   6.0
# 30211  not agent  not company                     0        Transient   6.0
# 32826       14.0  not company                     0  Transient-Party   6.0
# 39136      250.0  not company                     0        Transient  12.0
# 41745       13.0  not company                     0  Transient-Party   6.0
# 50277      240.0  not company                     0        Transient  12.0
# 58452        9.0  not company                     0  Transient-Party   6.0
# 60876        9.0  not company                     0        Transient   6.0
#
#        required_car_parking_spaces  total_of_special_requests  is_canceled  \
# 4106                             0                          0        False
# 9906                             0                          0        False
# 9970                             0                          0        False
# 10895                            0                          1        False
# 13999                            0                          1        False
# 14854                            0                          1         True
# 19982                            0                          2        False
# 21315                            1                          0        False
# 30190                            0                          1         True
# 30211                            0                          1        False
# 32826                            0                          1        False
# 39136                            0                          1        False
# 41745                            0                          1         True
# 50277                            0                          0         True
# 58452                            0                          1        False
# 60876                            0                          1        False
#
#        scores_AdrChildren  outlier_label_scores_AdrChildren
# 4106            -0.098948                                -1
# 9906            -0.107622                                -1
# 9970            -0.107622                                -1
# 10895           -0.101533                                -1
# 13999           -0.107622                                -1
# 14854           -0.107622                                -1
# 19982           -0.098948                                -1
# 21315           -0.107622                                -1
# 30190           -0.107622                                -1
# 30211           -0.107622                                -1
# 32826           -0.107622                                -1
# 39136           -0.103975                                -1
# 41745           -0.107622                                -1
# 50277           -0.103975                                -1
# 58452           -0.107622                                -1
# 60876           -0.107622                                -1

# %% [markdown]
# Es un grupo que se aparta del comportamiento común, pero los dejaremos ya que is_canceled en casi todos los casos es false, por lo que es importante para nuestro objetivo.

# %% [markdown]
# ##adr y lead_time

# %% [markdown]
# Veamos el análisis con isolation forest de adr y lead_time

# %%
model = IsolationForest(n_estimators=100, max_samples='auto', contamination=0.05, random_state=42)
model.fit(df_hotel[['lead_time', 'adr']])
anomaly_scores = model.decision_function(df_hotel[['lead_time', 'adr']])
anomaly_labels = model.predict(df_hotel[['lead_time', 'adr']])
df_hotel_isolation['scores_AdrLeed_time']=anomaly_scores
df_hotel_isolation['outlier_label_scores_AdrLeed_time']=anomaly_labels
print("Outliers encontrados:",df_hotel_mahalanobis[df_hotel_mahalanobis.outlier_label==-1].shape[0])
# Out:
# Outliers encontrados: 2362

# %% [markdown]
# Ahora veamos el diagrama de dispersión-

# %%
color = [f"C{n+1}" for n in df_hotel_isolation['outlier_label_scores_AdrChildren'].values]
sns.scatterplot(data=df_hotel_isolation, x="lead_time", y="adr", hue=color)
plt.title('Diagrama de Dispersión lead_time vs adr')
plt.grid(True)
plt.show()

# %% [markdown]
# Hay un gran cantidad de outliers, pero a nuestro parecer, son casos posibles que no se alejan mucho del comportamineto común, por lo que dejaremos los datos.
